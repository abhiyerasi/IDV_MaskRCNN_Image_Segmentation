# %% [markdown]
# # Data Augmentation on Pre Trained Weights

# %% [markdown]
# After runnning initial training on .ipynb file further training has been doen based on the weights which were generated by them for further training.

# %%
# %run -i main.py train --dataset='/volumes/notebooks/Final IDV/samples/idvscript' --weights='mask_rcnn_idv_0050.h5'
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Weights:  mask_rcnn_idv_0050.h5
# Dataset:  /volumes/notebooks/Final IDV/samples/idvscript
# Logs:  /volumes/notebooks/Final IDV/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.6
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# ...
